# %%
import pandas as pd

# Load dataset
df = pd.read_csv(
    "resources/household_power_consumption.txt",
    sep=";",
    low_memory=False,
    na_values="?"
)

# Drop the column (safe even if missing)
df.drop("Sub_metering_1", axis=1, inplace=True, errors="ignore")

# Save to CSV
df.to_csv("resources/cleaned_household_power.csv", index=False)

print("Cleaned CSV saved successfully!")
# Out:
# Cleaned CSV saved successfully!
